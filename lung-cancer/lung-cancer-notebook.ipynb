# %%
from omop_metadata_utils import DistributionCodesets, count_bar

# %%
table_names = {
    "tre1": "data/nottingham-tre-1.json",
    "tre2": "data/nottingham-tre-2.json"
}

codesets = DistributionCodesets(table_names)

# %%
codesets.plot_count_heatmap().properties(width=600, height=600)
# Out:
# alt.Chart(...)

# %%
codesets.plot_top_k_by_count(20)
# Out:
# alt.Chart(...)

# %%
codesets.tables["tre1"].head(20)
# Out:
#      TRE BIOBANK           CODE  COUNT  ALTERNATIVES  DATASET      OMOP  \
# 0   tre1    test    OMOP:313217    410           NaN      NaN    313217
# 1   tre1    test    OMOP:317576    630           NaN      NaN    317576
# 2   tre1    test    OMOP:321042    260           NaN      NaN    321042
# 3   tre1    test    OMOP:381316    490           NaN      NaN    381316
# 4   tre1    test    OMOP:439777     40           NaN      NaN    439777
# 5   tre1    test   OMOP:4115276     40           NaN      NaN   4115276
# 6   tre1    test   OMOP:4310703     40           NaN      NaN   4310703
# 7   tre1    test   OMOP:4329847    240           NaN      NaN   4329847
# 8   tre1    test  OMOP:38003563    610           NaN      NaN  38003563
# 9   tre1    test  OMOP:38003564   4770           NaN      NaN  38003564
# 10  tre1    test   OMOP:1310034    100           NaN      NaN   1310034
# 11  tre1    test   OMOP:1332419    570           NaN      NaN   1332419
# ...

# %%
codesets.tables["tre1"].head(20)
# Out:
#      TRE BIOBANK           CODE  COUNT  ALTERNATIVES  DATASET      OMOP  \
# 0   tre1    test    OMOP:313217    410           NaN      NaN    313217
# 1   tre1    test    OMOP:317576    630           NaN      NaN    317576
# 2   tre1    test    OMOP:321042    260           NaN      NaN    321042
# 3   tre1    test    OMOP:381316    490           NaN      NaN    381316
# 4   tre1    test    OMOP:439777     40           NaN      NaN    439777
# 5   tre1    test   OMOP:4115276     40           NaN      NaN   4115276
# 6   tre1    test   OMOP:4310703     40           NaN      NaN   4310703
# 7   tre1    test   OMOP:4329847    240           NaN      NaN   4329847
# 8   tre1    test  OMOP:38003563    610           NaN      NaN  38003563
# 9   tre1    test  OMOP:38003564   4770           NaN      NaN  38003564
# 10  tre1    test   OMOP:1310034    100           NaN      NaN   1310034
# 11  tre1    test   OMOP:1332419    570           NaN      NaN   1332419
# ...
