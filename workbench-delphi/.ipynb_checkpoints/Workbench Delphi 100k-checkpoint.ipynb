# %%
from pathlib import Path
from typing import Literal

from five_safes_tes_workbench.workbench import Workbench
from monoidal_aggregation.inner_functions import SumOfSquaresIntermediate
from monoidal_aggregation.outer_functions import sum_intermediates, gather_avg_intermediates, gather_var_intermediates
from omop_metadata_utils import DistributionCodesets, count_bar
import pandas as pd

# %%
def collect_var_data(path: Path, condition_status: Literal["with", "without"]) -> SumOfSquaresIntermediate:
    data = pd.read_csv(path)
    row_data = data[data["condition_status"] == condition_status]
    return SumOfSquaresIntermediate(
        count=row_data["count"].iloc[0],
        sum=row_data["sum"].iloc[0],
        sumsq=row_data["sumsq"].iloc[0]
    )

collect_var_data("data/neoplasm-systol-tre1.csv", "with")
# Out:
# SumOfSquaresIntermediate(sum=np.float64(63987.0), sumsq=np.float64(7640471.0), count=np.int64(536))

# %%
class StatsAggregator:
    def __init__(
        self,
        paths
    ):
        self.data

# %%
data_paths = [Path("data/neoplasm-systol-tre1.csv"), Path("data/neoplasm-systol-tre2.csv")]
with_condition_intermediates = [collect_var_data(p, "with") for p in data_paths]
without_condition_intermediates = [collect_var_data(p, "without") for p in data_paths]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 sum_intermediates.run(with_condition_intermediates)
#
# File ~/Documents/GitHub/5s-TES-notebooks/.venv/lib/python3.13/site-packages/monoidal_aggregation/aggregate_functions.py:41, in OuterFunction.run(self, intermediates)
#      37 def run(self, intermediates: Iterable[S]) -> R:
#      38     """
#      39     Calls the `aggregate` function on the intermediates, then uses `finalise` to produce the final result
#      40     """
# ---> 41     return self.finalise(reduce(self.aggregate, intermediates))
#
# File ~/Documents/GitHub/5s-TES-notebooks/.venv/lib/python3.13/site-packages/monoidal_aggregation/outer_functions.py:7, in <lambda>(a, b)
#       3 from .aggregate_functions import OuterFunction
#       4 from .inner_functions import SumIntermediate, SumOfSquaresIntermediate
#       6 sum_intermediates = OuterFunction[float, float](
# ----> 7         aggregate=lambda a, b: a + b,
#       8         identity=0,
#       9         finalise=lambda x: x
#      10         )
#      12 gather_avg_intermediates = OuterFunction[SumIntermediate, float](
#      13         aggregate=lambda a, b: SumIntermediate(sum=a.sum + b.sum, count=a.count + b.count),
#      14         identity=SumIntermediate(0,0),
#      15         finalise=lambda x: x.sum/x.count
#      16         )
#      18 gather_var_intermediates = OuterFunction[SumOfSquaresIntermediate, float](
#      19         aggregate=lambda a, b: SumOfSquaresIntermediate(sum=a.sum+b.sum, sumsq=a.sumsq + b.sumsq, count = a.count + b.count),
#      20         identity=SumOfSquaresIntermediate(0,0,0),
#      21         finalise=lambda x: x.sumsq/x.count - (x.sum/x.count * x.sum/x.count)
#      22         )
#
# TypeError: unsupported operand type(s) for +: 'SumOfSquaresIntermediate' and 'SumOfSquaresIntermediate'
